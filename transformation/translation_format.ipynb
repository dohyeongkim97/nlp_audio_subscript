# %%
import json
import urllib.request
import secret
from secret import *

# %%
client_id = "POwycgD6T59b5GBzC_f0"
client_pw = "oBhZcgkBpp"
client_url= "https://openapi.naver.com/v1/papago/n2mt"

# %% [markdown]
# https://developers.naver.com/apps/#/list
# 여기서 어플리케이션 등록

# %%
encText = urllib.parse.quote("안녕하세요 저는 김도형입니다") # 번역할 내용
data = "source=ko&target=en&text=" + encText #source의 언어를 target의 언어로 변환
url = client_url # 네이버 api 등록된 개인 주소
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id) # 네이버 api 등록된 개인 id
request.add_header("X-Naver-Client-Secret",client_pw) # 네이버 api 등록된 개인 비밀번호
response = urllib.request.urlopen(request, data=data.encode("utf-8"))
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# {"message":{"@type":"response","@service":"naverservice.nmt.proxy","@version":"1.0.0","result":{"srcLangType":"ko","tarLangType":"en","translatedText":"Hello, I'm Kim Dohyung","engineType":"N2MT"}}}

# %%
def get_translate(text):
    langue = get_langue(text)
    data = 'source='+str(langue)+'&target=ko&text='+text
    url = "https://naver.com/dohyeong_kim/papago_translations"
    request = urllib.request.Request(url)
    request.add_header("X-Naver-Client-ID", "N08HoWo9ma9BtseyoBea")
    request.add_header("X-Naver-Client-Secret", "a0CWlyXPJL")
    response = urllib.request.urlopen(request, data=data.encode('utf-8'))
    rescode = response.getcode()

    if rescode==200:
        response_body = response.read()
        result = json.loads(response_body)
        return result['message']['result']['translatedText']

    else:
        print('error code:', rescode)


def get_langue(text):
    content = 'query='+text
    url = 'https://naver.com/dohyeong_kim/papago_translations'
    request = urllib.request.Request(url)
    request.add_header("X-Naver-Client-Id", client_id)
    request.add_header("X-Naver-Client-Secret", client_pw)
    response = urllib.request.urlopen(request, data=content.encode('utf-8'))
    rescode = response.getcode()
    if rescode==200:
        response_body = response.read()
        langue = json.loads(response_body)
        return langue['langCode']
    else:
        print('error code:', rescode)

print(get_translate("hello"))
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[17], line 35
#      32     else:
#      33         print('error code:', rescode)
# ---> 35 print(get_translate("hello"))
#
# Cell In[17], line 2, in get_translate(text)
#       1 def get_translate(text):
# ----> 2     langue = get_langue(text)
#       3     data = 'source='+str(langue)+'&target=ko&text='+text
#       4     url = "https://naver.com/dohyeong_kim/papago_translations"
#
# Cell In[17], line 26, in get_langue(text)
#      24 request.add_header("X-Naver-Client-Id", client_id)
#      25 request.add_header("X-Naver-Client-Secret", client_pw)
# ---> 26 response = urllib.request.urlopen(request, data=content.encode('utf-8'))
#      27 rescode = response.getcode()
#      28 if rescode==200:
#
# ...
